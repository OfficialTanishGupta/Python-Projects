# %%
import numpy as np

# %%
marks = np.array([
    [85, 78, 92, 88, 76],
    [72, 81, 69, 75, 80],
    [91, 95, 89, 94, 90],
    [60, 65, 58, 70, 62],
    [78, 84, 80, 76, 85]
])

# %%
print(marks.shape)
# Out:
# (5, 5)

# %%
print(marks.shape[0])
# Out:
# 5

# %%
print(marks.shape[1])
# Out:
# 5

# %%
print(marks.sum(axis=1))
# Out:
# [419 377 459 315 403]

# %%
print(marks.mean(axis=1))
# Out:
# [83.8 75.4 91.8 63.  80.6]

# %%
print(marks.mean(axis=0))
# Out:
# [77.2 80.6 77.6 80.6 78.6]

# %% [markdown]
# ### Indexing and slicing

# %%
marks[0]
# Out:
# array([85, 78, 92, 88, 76])

# %%
marks[:, 0]
# Out:
# array([85, 72, 91, 60, 78])

# %%
marks[:, 2]
# Out:
# array([92, 69, 89, 58, 80])

# %%
marks[:3]
# Out:
# array([[85, 78, 92, 88, 76],
#        [72, 81, 69, 75, 80],
#        [91, 95, 89, 94, 90]])

# %%
marks[:, :3]
# Out:
# array([[85, 78, 92],
#        [72, 81, 69],
#        [91, 95, 89],
#        [60, 65, 58],
#        [78, 84, 80]])
